# %% [markdown]
# Generating transition list for skyline for a given molecule ID

# %%
# Generate a Skyline transition list **for a single row number** (e.g., 10)
# Ignores all other columns in the file.
#
# Expected columns in the CSV (case-insensitive; other columns are ignored):
#   - molecule
#   - matched_z_list
#   - matched_mz_list
#   - (optional) polarity / plolarity
#
# Output CSV columns (Skyline Small Molecule transition list):
#   Molecule, Precursor m/z, Precursor Adduct, Polarity
#
# Notes:
# - ROW_NUM is 1-based (ROW_NUM=10 means "the 10th row" in the file).
# - Charges of 0 are discarded. If polarity is missing/blank, defaults to Positive.

import re
from pathlib import Path
from typing import List, Optional
import pandas as pd

# ----------------------------
# EDIT THESE IF NEEDED
# ----------------------------
INPUT_PATH  = r"F:/20251005/input.csv"               # or "input.csv" or absolute path
OUTPUT_PATH = r"F:/20251005/transition_list_13352.csv"
ROW_NUM     = 1  # 1-based: e.g., 10 -> process only the 10th row
# ----------------------------

def extract_int_list(s) -> List[int]:
    if pd.isna(s):
        return []
    # Accept anything like: [2, 3, 4], "2,3,4", "z=2;3;4", etc.
    return [int(x) for x in re.findall(r"[-+]?\d+", str(s))]

def extract_float_list(s) -> List[float]:
    if pd.isna(s):
        return []
    # Accept 123, 123.4, .45, 1e3, -2.5E-2, etc.
    pattern = r"[-+]?(?:\d+\.\d*|\.\d+|\d+)(?:[eE][-+]?\d+)?"
    return [float(x) for x in re.findall(pattern, str(s))]

def norm_polarity(val) -> str:
    if val is None or str(val).strip().lower() in ("", "nan", "none"):
        return "Positive"
    return "Negative" if str(val).strip().lower().startswith("neg") else "Positive"

def adduct_from_charge(z: int, polarity: str = "Positive") -> str:
    # Skyline adduct notation from integer charge + polarity
    try:
        z = int(round(float(z)))
    except Exception:
        z = 1
    if z == 0:
        z = 1
    if str(polarity).lower().startswith("neg"):
        return f"[M-{abs(z)}H]{abs(z)}-"
    else:
        return f"[M+{abs(z)}H]{abs(z)}+"

def find_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    # Case-insensitive lookup; returns the actual column name if found
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        c = cand.lower()
        if c in lower_map:
            return lower_map[c]
    return None

# --- Load CSV (ignore extra columns, we will only touch what we need) ---
p = Path(INPUT_PATH)
if not p.exists():
    raise FileNotFoundError(f"Input file not found: {INPUT_PATH}")

# Read all (cheapest is to read the file; we will ignore extra columns downstream)
df_full = pd.read_csv(p, low_memory=False)

# Validate row number (1-based)
if ROW_NUM < 1 or ROW_NUM > len(df_full):
    raise IndexError(f"ROW_NUM={ROW_NUM} is out of range (file has {len(df_full)} rows).")

# Pick only the single row requested
df = df_full.iloc[[ROW_NUM - 1]].copy()

# --- Identify required columns (case-insensitive) ---
molecule_col = find_col(df, ["molecule"])
zlist_col    = find_col(df, ["matched_z_list"])
mzlist_col   = find_col(df, ["matched_mz_list"])
pol_col      = find_col(df, ["polarity", "plolarity"])  # accept common misspelling

if not molecule_col or not zlist_col or not mzlist_col:
    raise ValueError(
        "Missing required columns. Need at least: 'molecule', 'matched_z_list', 'matched_mz_list'. "
        f"Found: {list(df.columns)}"
    )

# Force types we care about
df[molecule_col] = df[molecule_col].astype(str)

# --- Build transitions for the single row ---
rows, skipped = [], []
r = df.iloc[0]
mol = r[molecule_col]
pol = norm_polarity(r[pol_col] if pol_col in df.columns else None)
z_list  = extract_int_list(r[zlist_col])
mz_list = extract_float_list(r[mzlist_col])

n = min(len(z_list), len(mz_list))
if n == 0:
    skipped.append((ROW_NUM, mol, "empty or unparsable matched_z_list/matched_mz_list"))
else:
    for z, mz in zip(z_list[:n], mz_list[:n]):
        try:
            z_int = int(z)
        except Exception:
            skipped.append((ROW_NUM, mol, f"non-integer charge '{z}' discarded"))
            continue
        if z_int == 0:
            skipped.append((ROW_NUM, mol, "charge=0 discarded"))
            continue
        rows.append({
            "Molecule": mol,
            "Precursor m/z": f"{float(mz):.6f}",
            "Precursor Adduct": adduct_from_charge(z_int, pol),
            "Polarity": pol
        })

transitions = pd.DataFrame(rows).drop_duplicates().reset_index(drop=True)

# --- Save CSV for Skyline ---
out_path = Path(OUTPUT_PATH)
out_path.parent.mkdir(parents=True, exist_ok=True)

# Ensure correct column order even if empty
wanted_cols = ["Molecule", "Precursor m/z", "Precursor Adduct", "Polarity"]
for c in wanted_cols:
    if c not in transitions.columns:
        transitions[c] = []
transitions = transitions[wanted_cols]

transitions.to_csv(out_path, index=False)

# --- Minimal console feedback ---
print(f"Processed only row #{ROW_NUM} from: {p.resolve()}")
print(f"Generated transitions: {len(transitions)}")
if skipped:
    print("Skipped entries (up to 10 shown):")
    for tup in skipped[:10]:
        print("  Row:", tup[0], "| Molecule:", tup[1], "| Reason:", tup[2])
print("Saved →", out_path.resolve())
# Out:
# Processed only row #1 from: F:\20251005\input.csv
# Generated transitions: 16
# Saved → F:\20251005\transition_list_13352.csv

# %% [markdown]
# Generating transition lists for all the molecules

# %%
# Generate Skyline transition lists for ALL rows
# One output CSV per row, with molecule name in the filename.
#
# Expected input columns (case-insensitive; others ignored):
#   - molecule
#   - matched_z_list
#   - matched_mz_list
#   - (optional) polarity / plolarity
#
# Output CSV columns (Skyline Small Molecule transition list):
#   Molecule, Precursor m/z, Precursor Adduct, Polarity

import re
import string
from pathlib import Path
from typing import List, Optional
import pandas as pd

# ----------------------------
# EDIT THESE IF NEEDED
# ----------------------------
INPUT_PATH = r"F:/tissue/ids.csv"      # path to your input CSV
OUTPUT_DIR = r"F:/tissue/transitions"      # folder where per-molecule CSVs will be saved
FILENAME_PREFIX = "transition_list"        # prefix for each file name
# ----------------------------

def extract_int_list(s) -> List[int]:
    if pd.isna(s):
        return []
    # Accept anything like: [2, 3, 4], "2,3,4", "z=2;3;4", etc.
    return [int(x) for x in re.findall(r"[-+]?\d+", str(s))]

def extract_float_list(s) -> List[float]:
    if pd.isna(s):
        return []
    # Accept 123, 123.4, .45, 1e3, -2.5E-2, etc.
    pattern = r"[-+]?(?:\d+\.\d*|\.\d+|\d+)(?:[eE][-+]?\d+)?"
    return [float(x) for x in re.findall(pattern, str(s))]

def norm_polarity(val) -> str:
    if val is None or str(val).strip().lower() in ("", "nan", "none"):
        return "Positive"
    return "Negative" if str(val).strip().lower().startswith("neg") else "Positive"

def adduct_from_charge(z: int, polarity: str = "Positive") -> str:
    # Skyline adduct notation from integer charge + polarity
    try:
        z = int(round(float(z)))
    except Exception:
        z = 1
    if z == 0:
        z = 1
    if str(polarity).lower().startswith("neg"):
        return f"[M-{abs(z)}H]{abs(z)}-"
    else:
        return f"[M+{abs(z)}H]{abs(z)}+"

def find_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    # Case-insensitive lookup; returns the actual column name if found
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        c = cand.lower()
        if c in lower_map:
            return lower_map[c]
    return None

def safe_slug(text: str, max_len: int = 80) -> str:
    """Make a filesystem-safe slug from molecule name."""
    if text is None:
        text = "unknown"
    text = str(text).strip()
    # Replace spaces with underscores, drop disallowed chars
    allowed = f"-_.() {string.ascii_letters}{string.digits}"
    cleaned = "".join(ch if ch in allowed else "_" for ch in text)
    cleaned = "_".join(cleaned.split())  # collapse whitespace runs
    if not cleaned:
        cleaned = "unknown"
    return cleaned[:max_len]

def unique_path(base_path: Path) -> Path:
    """Return a unique path by appending -1, -2, ... if needed."""
    if not base_path.exists():
        return base_path
    stem, suffix = base_path.stem, base_path.suffix
    i = 1
    while True:
        candidate = base_path.with_name(f"{stem}-{i}{suffix}")
        if not candidate.exists():
            return candidate
        i += 1

# --- Load CSV ---
p = Path(INPUT_PATH)
if not p.exists():
    raise FileNotFoundError(f"Input file not found: {INPUT_PATH}")

df_full = pd.read_csv(p, low_memory=False)

# --- Identify required columns (case-insensitive) ---
molecule_col = find_col(df_full, ["molecule"])
zlist_col    = find_col(df_full, ["matched_z_list"])
mzlist_col   = find_col(df_full, ["matched_mz_list"])
pol_col      = find_col(df_full, ["polarity", "plolarity"])  # accept common misspelling

if not molecule_col or not zlist_col or not mzlist_col:
    raise ValueError(
        "Missing required columns. Need at least: 'molecule', 'matched_z_list', 'matched_mz_list'. "
        f"Found: {list(df_full.columns)}"
    )

# Force types we care about
df_full[molecule_col] = df_full[molecule_col].astype(str)

# Prepare output dir
out_dir = Path(OUTPUT_DIR)
out_dir.mkdir(parents=True, exist_ok=True)

wanted_cols = ["Molecule", "Precursor m/z", "Precursor Adduct", "Polarity"]

total_rows = len(df_full)
total_transitions = 0
skipped_overall = []

for idx0, r in df_full.iterrows():
    row_num = idx0 + 1  # 1-based for user-facing messages
    mol = r[molecule_col]
    pol = norm_polarity(r[pol_col] if pol_col in df_full.columns else None)
    z_list  = extract_int_list(r[zlist_col])
    mz_list = extract_float_list(r[mzlist_col])

    rows = []
    n = min(len(z_list), len(mz_list))
    if n == 0:
        skipped_overall.append((row_num, mol, "empty or unparsable matched_z_list/matched_mz_list"))
    else:
        for z, mz in zip(z_list[:n], mz_list[:n]):
            try:
                z_int = int(z)
            except Exception:
                skipped_overall.append((row_num, mol, f"non-integer charge '{z}' discarded"))
                continue
            if z_int == 0:
                skipped_overall.append((row_num, mol, "charge=0 discarded"))
                continue
            rows.append({
                "Molecule": mol,
                "Precursor m/z": f"{float(mz):.6f}",
                "Precursor Adduct": adduct_from_charge(z_int, pol),
                "Polarity": pol
            })

    transitions = pd.DataFrame(rows).drop_duplicates().reset_index(drop=True)
    # ensure column order even if empty
    for c in wanted_cols:
        if c not in transitions.columns:
            transitions[c] = []
    transitions = transitions[wanted_cols]

    # Build output filename with molecule name and row number
    mol_slug = safe_slug(mol)
    fname = f"{FILENAME_PREFIX}_{row_num:05d}_{mol_slug}.csv"
    out_path = unique_path(out_dir / fname)

    transitions.to_csv(out_path, index=False)
    total_transitions += len(transitions)

    print(f"[Row {row_num}/{total_rows}] {mol} -> {len(transitions)} transitions | Saved: {out_path.name}")

print(f"\nAll done. Total transitions across {total_rows} rows: {total_transitions}")
if skipped_overall:
    print("Skipped entries (up to 20 shown):")
    for tup in skipped_overall[:20]:
        print("  Row:", tup[0], "| Molecule:", tup[1], "| Reason:", tup[2])
print(f"Output folder → {Path(OUTPUT_DIR).resolve()}")
# Out:
# [Row 1/12741] P30049:15010 -> 16 transitions | Saved: transition_list_00001_P30049_15010.csv
# [Row 2/12741] P04179-1:22250 -> 22 transitions | Saved: transition_list_00002_P04179-1_22250.csv
# [Row 3/12741] :37900 -> 26 transitions | Saved: transition_list_00003__37900.csv
# [Row 4/12741] P68871:16210 -> 15 transitions | Saved: transition_list_00004_P68871_16210.csv
# [Row 5/12741] :29410 -> 31 transitions | Saved: transition_list_00005__29410.csv
# [Row 6/12741] P19429:24010 -> 24 transitions | Saved: transition_list_00006_P19429_24010.csv
# [Row 7/12741] Q9Y281-1:18610 -> 18 transitions | Saved: transition_list_00007_Q9Y281-1_18610.csv
# [Row 8/12741] :64900 -> 10 transitions | Saved: transition_list_00008__64900.csv
# [Row 9/12741] P45379-12:30820 -> 30 transitions | Saved: transition_list_00009_P45379-12_30820.csv
# [Row 10/12741] P06454-2:12010 -> 11 transitions | Saved: transition_list_00010_P06454-2_12010.csv
# [Row 11/12741] P19404:23750 -> 23 transitions | Saved: transition_list_00011_P19404_23750.csv
# [Row 12/12741] :59080 -> 14 transitions | Saved: transition_list_00012__59080.csv
# [Row 13/12741] :65410 -> 10 transitions | Saved: transition_list_00013__65410.csv
# [Row 14/12741] :32570 -> 28 transitions | Saved: transition_list_00014__32570.csv
# [Row 15/12741] :66970 -> 8 transitions | Saved: transition_list_00015__66970.csv
# [Row 16/12741] :28780 -> 28 transitions | Saved: transition_list_00016__28780.csv
# [Row 17/12741] :25810 -> 24 transitions | Saved: transition_list_00017__25810.csv
# [Row 18/12741] :27500 -> 25 transitions | Saved: transition_list_00018__27500.csv
# [Row 19/12741] P23528:19240 -> 18 transitions | Saved: transition_list_00019_P23528_19240.csv
# [Row 20/12741] :30000 -> 25 transitions | Saved: transition_list_00020__30000.csv
# [Row 21/12741] :26020 -> 23 transitions | Saved: transition_list_00021__26020.csv
# [Row 22/12741] P58876:13810 -> 12 transitions | Saved: transition_list_00022_P58876_13810.csv
# [Row 23/12741] O43567-2:29610 -> 29 transitions | Saved: transition_list_00023_O43567-2_29610.csv
# [Row 24/12741] P61204-1:20650 -> 19 transitions | Saved: transition_list_00024_P61204-1_20650.csv
# [Row 25/12741] :57660 -> 12 transitions | Saved: transition_list_00025__57660.csv
# [Row 26/12741] P24539:24610 -> 22 transitions | Saved: transition_list_00026_P24539_24610.csv
# [Row 27/12741] Q99714-1:26880 -> 25 transitions | Saved: transition_list_00027_Q99714-1_26880.csv
# [Row 28/12741] :71640 -> 6 transitions | Saved: transition_list_00028__71640.csv
# [Row 29/12741] P62937-1:18010 -> 14 transitions | Saved: transition_list_00029_P62937-1_18010.csv
# [Row 30/12741] P60174-1:26580 -> 23 transitions | Saved: transition_list_00030_P60174-1_26580.csv
# [Row 31/12741] :60740 -> 13 transitions | Saved: transition_list_00031__60740.csv
# [Row 32/12741] Q01995:22500 -> 18 transitions | Saved: transition_list_00032_Q01995_22500.csv
# [Row 33/12741] P02647:28150 -> 24 transitions | Saved: transition_list_00033_P02647_28150.csv
# [Row 34/12741] :44900 -> 22 transitions | Saved: transition_list_00034__44900.csv
# [Row 35/12741] P63104-1:27850 -> 25 transitions | Saved: transition_list_00035_P63104-1_27850.csv
# [Row 36/12741] :43720 -> 17 transitions | Saved: transition_list_00036__43720.csv
# [Row 37/12741] P10606:10640 -> 10 transitions | Saved: transition_list_00037_P10606_10640.csv
# [Row 38/12741] P56134-2:10270 -> 9 transitions | Saved: transition_list_00038_P56134-2_10270.csv
# [Row 39/12741] :31100 -> 27 transitions | Saved: transition_list_00039__31100.csv
# [Row 40/12741] :64570 -> 9 transitions | Saved: transition_list_00040__64570.csv
# [Row 41/12741] O14548:12610 -> 11 transitions | Saved: transition_list_00041_O14548_12610.csv
# [Row 42/12741] :55630 -> 15 transitions | Saved: transition_list_00042__55630.csv
# [Row 43/12741] :34030 -> 22 transitions | Saved: transition_list_00043__34030.csv
# [Row 44/12741] Q96QD9-1:35820 -> 22 transitions | Saved: transition_list_00044_Q96QD9-1_35820.csv
# [Row 45/12741] :62250 -> 10 transitions | Saved: transition_list_00045__62250.csv
# [Row 46/12741] O60814:7740 -> 7 transitions | Saved: transition_list_00046_O60814_7740.csv
# [Row 47/12741] :46080 -> 17 transitions | Saved: transition_list_00047__46080.csv
# [Row 48/12741] :59600 -> 11 transitions | Saved: transition_list_00048__59600.csv
# [Row 49/12741] P69905:15610 -> 11 transitions | Saved: transition_list_00049_P69905_15610.csv
# [Row 50/12741] :61170 -> 10 transitions | Saved: transition_list_00050__61170.csv
# [Row 51/12741] P60201-2:27080 -> 21 transitions | Saved: transition_list_00051_P60201-2_27080.csv
# [Row 52/12741] Q86W42-2:34810 -> 21 transitions | Saved: transition_list_00052_Q86W42-2_34810.csv
# [Row 53/12741] Q99497:19810 -> 15 transitions | Saved: transition_list_00053_Q99497_19810.csv
# [Row 54/12741] :38680 -> 16 transitions | Saved: transition_list_00054__38680.csv
# [Row 55/12741] :50330 -> 16 transitions | Saved: transition_list_00055__50330.csv
# [Row 56/12741] :25040 -> 20 transitions | Saved: transition_list_00056__25040.csv
# [Row 57/12741] P63267-2:37130 -> 17 transitions | Saved: transition_list_00057_P63267-2_37130.csv
# [Row 58/12741] P06702:13210 -> 6 transitions | Saved: transition_list_00058_P06702_13210.csv
# [Row 59/12741] :70080 -> 5 transitions | Saved: transition_list_00059__70080.csv
# [Row 60/12741] P10916:18870 -> 16 transitions | Saved: transition_list_00060_P10916_18870.csv
# [Row 61/12741] P42766:14410 -> 7 transitions | Saved: transition_list_00061_P42766_14410.csv
# [Row 62/12741] :26300 -> 20 transitions | Saved: transition_list_00062__26300.csv
# [Row 63/12741] P62750:17610 -> 14 transitions | Saved: transition_list_00063_P62750_17610.csv
# [Row 64/12741] P02511:20160 -> 13 transitions | Saved: transition_list_00064_P02511_20160.csv
# [Row 65/12741] P84243:9280 -> 5 transitions | Saved: transition_list_00065_P84243_9280.csv
# [Row 66/12741] :28570 -> 24 transitions | Saved: transition_list_00066__28570.csv
# [Row 67/12741] P07305:10010 -> 5 transitions | Saved: transition_list_00067_P07305_10010.csv
# [Row 68/12741] P07148:14180 -> 7 transitions | Saved: transition_list_00068_P07148_14180.csv
# [Row 69/12741] :57400 -> 12 transitions | Saved: transition_list_00069__57400.csv
# [Row 70/12741] :58190 -> 11 transitions | Saved: transition_list_00070__58190.csv
# [Row 71/12741] :68500 -> 6 transitions | Saved: transition_list_00071__68500.csv
# [Row 72/12741] :63480 -> 11 transitions | Saved: transition_list_00072__63480.csv
# [Row 73/12741] :47680 -> 17 transitions | Saved: transition_list_00073__47680.csv
# [Row 74/12741] :60540 -> 12 transitions | Saved: transition_list_00074__60540.csv
# [Row 75/12741] :44420 -> 16 transitions | Saved: transition_list_00075__44420.csv
# [Row 76/12741] :48450 -> 15 transitions | Saved: transition_list_00076__48450.csv
# [Row 77/12741] P69905:15360 -> 10 transitions | Saved: transition_list_00077_P69905_15360.csv
# [Row 78/12741] :29140 -> 15 transitions | Saved: transition_list_00078__29140.csv
# [Row 79/12741] :21270 -> 9 transitions | Saved: transition_list_00079__21270.csv
# [Row 80/12741] :38940 -> 17 transitions | Saved: transition_list_00080__38940.csv
# [Row 81/12741] P05067-2:30420 -> 21 transitions | Saved: transition_list_00081_P05067-2_30420.csv
# [Row 82/12741] :59320 -> 10 transitions | Saved: transition_list_00082__59320.csv
# [Row 83/12741] :57900 -> 10 transitions | Saved: transition_list_00083__57900.csv
# [Row 84/12741] :46950 -> 17 transitions | Saved: transition_list_00084__46950.csv
# [Row 85/12741] P08590:21870 -> 15 transitions | Saved: transition_list_00085_P08590_21870.csv
# [Row 86/12741] :53020 -> 11 transitions | Saved: transition_list_00086__53020.csv
# [Row 87/12741] :32310 -> 20 transitions | Saved: transition_list_00087__32310.csv
# [Row 88/12741] :52780 -> 13 transitions | Saved: transition_list_00088__52780.csv
# [Row 89/12741] :49960 -> 15 transitions | Saved: transition_list_00089__49960.csv
# [Row 90/12741] :69480 -> 4 transitions | Saved: transition_list_00090__69480.csv
# [Row 91/12741] :73290 -> 5 transitions | Saved: transition_list_00091__73290.csv
# [Row 92/12741] :32050 -> 18 transitions | Saved: transition_list_00092__32050.csv
# [Row 93/12741] :58760 -> 10 transitions | Saved: transition_list_00093__58760.csv
# [Row 94/12741] P56385:7950 -> 5 transitions | Saved: transition_list_00094_P56385_7950.csv
# [Row 95/12741] P61254:17270 -> 9 transitions | Saved: transition_list_00095_P61254_17270.csv
# [Row 96/12741] Q9UII2-1:9520 -> 5 transitions | Saved: transition_list_00096_Q9UII2-1_9520.csv
# [Row 97/12741] P07741-1:19530 -> 15 transitions | Saved: transition_list_00097_P07741-1_19530.csv
# [Row 98/12741] P09210:25500 -> 18 transitions | Saved: transition_list_00098_P09210_25500.csv
# [Row 99/12741] Q16777:11420 -> 8 transitions | Saved: transition_list_00099_Q16777_11420.csv
# [Row 100/12741] P14927-1:13480 -> 9 transitions | Saved: transition_list_00100_P14927-1_13480.csv
# [Row 101/12741] :49460 -> 13 transitions | Saved: transition_list_00101__49460.csv
# [Row 102/12741] P63267-2:36860 -> 15 transitions | Saved: transition_list_00102_P63267-2_36860.csv
# [Row 103/12741] :41760 -> 13 transitions | Saved: transition_list_00103__41760.csv
# [Row 104/12741] :45570 -> 15 transitions | Saved: transition_list_00104__45570.csv
# [Row 105/12741] :24340 -> 10 transitions | Saved: transition_list_00105__24340.csv
# [Row 106/12741] :33270 -> 10 transitions | Saved: transition_list_00106__33270.csv
# [Row 107/12741] :40370 -> 13 transitions | Saved: transition_list_00107__40370.csv
# [Row 108/12741] :68300 -> 6 transitions | Saved: transition_list_00108__68300.csv
# [Row 109/12741] :31790 -> 15 transitions | Saved: transition_list_00109__31790.csv
# [Row 110/12741] P30086:20990 -> 13 transitions | Saved: transition_list_00110_P30086_20990.csv
# [Row 111/12741] :56180 -> 9 transitions | Saved: transition_list_00111__56180.csv
# [Row 112/12741] :46490 -> 15 transitions | Saved: transition_list_00112__46490.csv
# [Row 113/12741] P60903:11100 -> 4 transitions | Saved: transition_list_00113_P60903_11100.csv
# [Row 114/12741] :41530 -> 15 transitions | Saved: transition_list_00114__41530.csv
# [Row 115/12741] :66110 -> 5 transitions | Saved: transition_list_00115__66110.csv
# [Row 116/12741] Q9P0J0-1:16610 -> 9 transitions | Saved: transition_list_00116_Q9P0J0-1_16610.csv
# [Row 117/12741] :56950 -> 9 transitions | Saved: transition_list_00117__56950.csv
# [Row 118/12741] :51020 -> 7 transitions | Saved: transition_list_00118__51020.csv
# [Row 119/12741] :56750 -> 4 transitions | Saved: transition_list_00119__56750.csv
# [Row 120/12741] :43160 -> 12 transitions | Saved: transition_list_00120__43160.csv
# [Row 121/12741] :60970 -> 6 transitions | Saved: transition_list_00121__60970.csv
# [Row 122/12741] :62710 -> 7 transitions | Saved: transition_list_00122__62710.csv
# [Row 123/12741] Q9BPX5:16850 -> 10 transitions | Saved: transition_list_00123_Q9BPX5_16850.csv
# [Row 124/12741] :53900 -> 8 transitions | Saved: transition_list_00124__53900.csv
# [Row 125/12741] P09211:23210 -> 6 transitions | Saved: transition_list_00125_P09211_23210.csv
# [Row 126/12741] Q96KB5-1:36360 -> 14 transitions | Saved: transition_list_00126_Q96KB5-1_36360.csv
# [Row 127/12741] :63730 -> 5 transitions | Saved: transition_list_00127__63730.csv
# [Row 128/12741] :23480 -> 11 transitions | Saved: transition_list_00128__23480.csv
# [Row 129/12741] :31300 -> 13 transitions | Saved: transition_list_00129__31300.csv
# [Row 130/12741] P23284:20370 -> 10 transitions | Saved: transition_list_00130_P23284_20370.csv
# [Row 131/12741] :47960 -> 8 transitions | Saved: transition_list_00131__47960.csv
# [Row 132/12741] P00846:24830 -> 11 transitions | Saved: transition_list_00132_P00846_24830.csv
# [Row 133/12741] :46290 -> 9 transitions | Saved: transition_list_00133__46290.csv
# [Row 134/12741] P04792:22920 -> 8 transitions | Saved: transition_list_00134_P04792_22920.csv
# [Row 135/12741] :42940 -> 13 transitions | Saved: transition_list_00135__42940.csv
# [Row 136/12741] :59870 -> 5 transitions | Saved: transition_list_00136__59870.csv
# [Row 137/12741] :45130 -> 8 transitions | Saved: transition_list_00137__45130.csv
# [Row 138/12741] P00738-1:15950 -> 7 transitions | Saved: transition_list_00138_P00738-1_15950.csv
# [Row 139/12741] :21540 -> 13 transitions | Saved: transition_list_00139__21540.csv
# [Row 140/12741] :52500 -> 7 transitions | Saved: transition_list_00140__52500.csv
# [Row 141/12741] :51650 -> 5 transitions | Saved: transition_list_00141__51650.csv
# [Row 142/12741] :39260 -> 7 transitions | Saved: transition_list_00142__39260.csv
# [Row 143/12741] :38300 -> 11 transitions | Saved: transition_list_00143__38300.csv
# [Row 144/12741] :63030 -> 5 transitions | Saved: transition_list_00144__63030.csv
# [Row 145/12741] Q16836-1:33060 -> 7 transitions | Saved: transition_list_00145_Q16836-1_33060.csv
# [Row 146/12741] :34510 -> 10 transitions | Saved: transition_list_00146__34510.csv
# [Row 147/12741] :53390 -> 10 transitions | Saved: transition_list_00147__53390.csv
# [Row 148/12741] P10412:10880 -> 6 transitions | Saved: transition_list_00148_P10412_10880.csv
# [Row 149/12741] :48190 -> 9 transitions | Saved: transition_list_00149__48190.csv
# [Row 150/12741] P30086:21010 -> 22 transitions | Saved: transition_list_00150_P30086_21010.csv
# [Row 151/12741] P30049:15010 -> 14 transitions | Saved: transition_list_00151_P30049_15010.csv
# [Row 152/12741] P68871:16270 -> 15 transitions | Saved: transition_list_00152_P68871_16270.csv
# [Row 153/12741] Q01995:22600 -> 20 transitions | Saved: transition_list_00153_Q01995_22600.csv
# [Row 154/12741] :29410 -> 29 transitions | Saved: transition_list_00154__29410.csv
# [Row 155/12741] P04179-1:22210 -> 21 transitions | Saved: transition_list_00155_P04179-1_22210.csv
# [Row 156/12741] :21250 -> 20 transitions | Saved: transition_list_00156__21250.csv
# [Row 157/12741] :66970 -> 7 transitions | Saved: transition_list_00157__66970.csv
# [Row 158/12741] Q9Y281-1:18610 -> 20 transitions | Saved: transition_list_00158_Q9Y281-1_18610.csv
# [Row 159/12741] P62937-1:18040 -> 16 transitions | Saved: transition_list_00159_P62937-1_18040.csv
# [Row 160/12741] Q9Y5N1-3:40770 -> 18 transitions | Saved: transition_list_00160_Q9Y5N1-3_40770.csv
# [Row 161/12741] P00338-4:30640 -> 27 transitions | Saved: transition_list_00161_P00338-4_30640.csv
# [Row 162/12741] :52980 -> 15 transitions | Saved: transition_list_00162__52980.csv
# [Row 163/12741] P10412:6600 -> 5 transitions | Saved: transition_list_00163_P10412_6600.csv
# [Row 164/12741] O60814:7740 -> 8 transitions | Saved: transition_list_00164_O60814_7740.csv
# [Row 165/12741] :30030 -> 23 transitions | Saved: transition_list_00165__30030.csv
# [Row 166/12741] Q9BTP6:25000 -> 21 transitions | Saved: transition_list_00166_Q9BTP6_25000.csv
# [Row 167/12741] :31230 -> 24 transitions | Saved: transition_list_00167__31230.csv
# [Row 168/12741] :32560 -> 24 transitions | Saved: transition_list_00168__32560.csv
# [Row 169/12741] P00403:25650 -> 22 transitions | Saved: transition_list_00169_P00403_25650.csv
# [Row 170/12741] :70080 -> 6 transitions | Saved: transition_list_00170__70080.csv
# [Row 171/12741] :31900 -> 23 transitions | Saved: transition_list_00171__31900.csv
# [Row 172/12741] P23528:19210 -> 16 transitions | Saved: transition_list_00172_P23528_19210.csv
# [Row 173/12741] :37900 -> 20 transitions | Saved: transition_list_00173__37900.csv
# [Row 174/12741] P60174-1:27240 -> 27 transitions | Saved: transition_list_00174_P60174-1_27240.csv
# [Row 175/12741] :27630 -> 21 transitions | Saved: transition_list_00175__27630.csv
# [Row 176/12741] P58876:13810 -> 10 transitions | Saved: transition_list_00176_P58876_13810.csv
# [Row 177/12741] Q53FV1:17410 -> 15 transitions | Saved: transition_list_00177_Q53FV1_17410.csv
# [Row 178/12741] P60174-1:26490 -> 22 transitions | Saved: transition_list_00178_P60174-1_26490.csv
# [Row 179/12741] :65410 -> 8 transitions | Saved: transition_list_00179__65410.csv
# [Row 180/12741] P06454-2:12010 -> 10 transitions | Saved: transition_list_00180_P06454-2_12010.csv
# [Row 181/12741] P27449:15630 -> 10 transitions | Saved: transition_list_00181_P27449_15630.csv
# [Row 182/12741] :54510 -> 13 transitions | Saved: transition_list_00182__54510.csv
# [Row 183/12741] :25910 -> 20 transitions | Saved: transition_list_00183__25910.csv
# [Row 184/12741] O43567-2:29610 -> 25 transitions | Saved: transition_list_00184_O43567-2_29610.csv
# [Row 185/12741] Q99497:19810 -> 13 transitions | Saved: transition_list_00185_Q99497_19810.csv
# [Row 186/12741] O14548:12610 -> 9 transitions | Saved: transition_list_00186_O14548_12610.csv
# [Row 187/12741] P07195:36630 -> 15 transitions | Saved: transition_list_00187_P07195_36630.csv
# [Row 188/12741] :42540 -> 13 transitions | Saved: transition_list_00188__42540.csv
# [Row 189/12741] :50370 -> 16 transitions | Saved: transition_list_00189__50370.csv
# [Row 190/12741] P19429:23970 -> 22 transitions | Saved: transition_list_00190_P19429_23970.csv
# [Row 191/12741] P30086:20020 -> 12 transitions | Saved: transition_list_00191_P30086_20020.csv
# [Row 192/12741] :29140 -> 19 transitions | Saved: transition_list_00192__29140.csv
# [Row 193/12741] :44420 -> 12 transitions | Saved: transition_list_00193__44420.csv
# [Row 194/12741] P58876:13230 -> 7 transitions | Saved: transition_list_00194_P58876_13230.csv
# [Row 195/12741] P78310-2:38410 -> 13 transitions | Saved: transition_list_00195_P78310-2_38410.csv
# [Row 196/12741] P23284:20410 -> 14 transitions | Saved: transition_list_00196_P23284_20410.csv
# [Row 197/12741] Q9BPX5:16850 -> 12 transitions | Saved: transition_list_00197_Q9BPX5_16850.csv
# [Row 198/12741] P47985:21610 -> 16 transitions | Saved: transition_list_00198_P47985_21610.csv
# [Row 199/12741] P62805:11410 -> 6 transitions | Saved: transition_list_00199_P62805_11410.csv
# [Row 200/12741] :43720 -> 9 transitions | Saved: transition_list_00200__43720.csv
# [Row 201/12741] P56385:7950 -> 5 transitions | Saved: transition_list_00201_P56385_7950.csv
# [Row 202/12741] :62250 -> 7 transitions | Saved: transition_list_00202__62250.csv
# [Row 203/12741] :28760 -> 19 transitions | Saved: transition_list_00203__28760.csv
# [Row 204/12741] P04792:22810 -> 12 transitions | Saved: transition_list_00204_P04792_22810.csv
# [Row 205/12741] P19404:23770 -> 16 transitions | Saved: transition_list_00205_P19404_23770.csv
# [Row 206/12741] :55630 -> 8 transitions | Saved: transition_list_00206__55630.csv
# [Row 207/12741] P56134-2:10270 -> 6 transitions | Saved: transition_list_00207_P56134-2_10270.csv
# [Row 208/12741] P09211:23250 -> 13 transitions | Saved: transition_list_00208_P09211_23250.csv
# [Row 209/12741] P05109:10830 -> 7 transitions | Saved: transition_list_00209_P05109_10830.csv
# [Row 210/12741] :25340 -> 18 transitions | Saved: transition_list_00210__25340.csv
# [Row 211/12741] P51397:11050 -> 10 transitions | Saved: transition_list_00211_P51397_11050.csv
# [Row 212/12741] :36860 -> 14 transitions | Saved: transition_list_00212__36860.csv
# [Row 213/12741] :60740 -> 8 transitions | Saved: transition_list_00213__60740.csv
# [Row 214/12741] :27900 -> 17 transitions | Saved: transition_list_00214__27900.csv
# [Row 215/12741] :59080 -> 7 transitions | Saved: transition_list_00215__59080.csv
# [Row 216/12741] P45379-6:34660 -> 13 transitions | Saved: transition_list_00216_P45379-6_34660.csv
# [Row 217/12741] :51990 -> 7 transitions | Saved: transition_list_00217__51990.csv
# [Row 218/12741] :50810 -> 12 transitions | Saved: transition_list_00218__50810.csv
# [Row 219/12741] :47680 -> 11 transitions | Saved: transition_list_00219__47680.csv
# [Row 220/12741] :71640 -> 4 transitions | Saved: transition_list_00220__71640.csv
# [Row 221/12741] Q9NYJ1-1:10040 -> 6 transitions | Saved: transition_list_00221_Q9NYJ1-1_10040.csv
# [Row 222/12741] Q9Y5U2-2:28260 -> 18 transitions | Saved: transition_list_00222_Q9Y5U2-2_28260.csv
# [Row 223/12741] P24539:24610 -> 15 transitions | Saved: transition_list_00223_P24539_24610.csv
# [Row 224/12741] :61490 -> 4 transitions | Saved: transition_list_00224__61490.csv
# [Row 225/12741] P05067-2:30420 -> 17 transitions | Saved: transition_list_00225_P05067-2_30420.csv
# [Row 226/12741] O95298-1:14180 -> 6 transitions | Saved: transition_list_00226_O95298-1_14180.csv
# [Row 227/12741] :44900 -> 10 transitions | Saved: transition_list_00227__44900.csv
# [Row 228/12741] :26280 -> 14 transitions | Saved: transition_list_00228__26280.csv
# [Row 229/12741] P62269:17680 -> 6 transitions | Saved: transition_list_00229_P62269_17680.csv
# [Row 230/12741] :58280 -> 6 transitions | Saved: transition_list_00230__58280.csv
# [Row 231/12741] :26710 -> 14 transitions | Saved: transition_list_00231__26710.csv
# [Row 232/12741] :24400 -> 11 transitions | Saved: transition_list_00232__24400.csv
# [Row 233/12741] :43000 -> 14 transitions | Saved: transition_list_00233__43000.csv
# [Row 234/12741] P68871:15870 -> 8 transitions | Saved: transition_list_00234_P68871_15870.csv
# [Row 235/12741] :70290 -> 4 transitions | Saved: transition_list_00235__70290.csv
# [Row 236/12741] P08590:21820 -> 13 transitions | Saved: transition_list_00236_P08590_21820.csv
# [Row 237/12741] :48340 -> 10 transitions | Saved: transition_list_00237__48340.csv
# [Row 238/12741] :31450 -> 12 transitions | Saved: transition_list_00238__31450.csv
# [Row 239/12741] :33110 -> 12 transitions | Saved: transition_list_00239__33110.csv
# [Row 240/12741] :63580 -> 4 transitions | Saved: transition_list_00240__63580.csv
# [Row 241/12741] :35450 -> 13 transitions | Saved: transition_list_00241__35450.csv
# [Row 242/12741] :56720 -> 5 transitions | Saved: transition_list_00242__56720.csv
# [Row 243/12741] :49630 -> 10 transitions | Saved: transition_list_00243__49630.csv
# [Row 244/12741] Q9P0J0-1:16610 -> 9 transitions | Saved: transition_list_00244_Q9P0J0-1_16610.csv
# [Row 245/12741] :28560 -> 11 transitions | Saved: transition_list_00245__28560.csv
# [Row 246/12741] P61204-1:20700 -> 10 transitions | Saved: transition_list_00246_P61204-1_20700.csv
# [Row 247/12741] :57660 -> 4 transitions | Saved: transition_list_00247__57660.csv
# [Row 248/12741] Q7Z7F7-1:11610 -> 5 transitions | Saved: transition_list_00248_Q7Z7F7-1_11610.csv
# [Row 249/12741] :52260 -> 6 transitions | Saved: transition_list_00249__52260.csv
# [Row 250/12741] :23450 -> 5 transitions | Saved: transition_list_00250__23450.csv
# [Row 251/12741] :41510 -> 11 transitions | Saved: transition_list_00251__41510.csv
# [Row 252/12741] :46080 -> 8 transitions | Saved: transition_list_00252__46080.csv
# [Row 253/12741] :60540 -> 6 transitions | Saved: transition_list_00253__60540.csv
# [Row 254/12741] :36350 -> 11 transitions | Saved: transition_list_00254__36350.csv
# [Row 255/12741] P02647:28160 -> 30 transitions | Saved: transition_list_00255_P02647_28160.csv
# [Row 256/12741] :34090 -> 29 transitions | Saved: transition_list_00256__34090.csv
# [Row 257/12741] P78310-2:38310 -> 27 transitions | Saved: transition_list_00257_P78310-2_38310.csv
# [Row 258/12741] P63104-1:27770 -> 29 transitions | Saved: transition_list_00258_P63104-1_27770.csv
# [Row 259/12741] P02144:17050 -> 18 transitions | Saved: transition_list_00259_P02144_17050.csv
# [Row 260/12741] P04792:22710 -> 23 transitions | Saved: transition_list_00260_P04792_22710.csv
# [Row 261/12741] P05067-2:30500 -> 31 transitions | Saved: transition_list_00261_P05067-2_30500.csv
# [Row 262/12741] :30090 -> 32 transitions | Saved: transition_list_00262__30090.csv
# [Row 263/12741] P09211:23190 -> 24 transitions | Saved: transition_list_00263_P09211_23190.csv
# [Row 264/12741] P42766:14370 -> 16 transitions | Saved: transition_list_00264_P42766_14370.csv
# [Row 265/12741] Q01105-1:33310 -> 30 transitions | Saved: transition_list_00265_Q01105-1_33310.csv
# [Row 266/12741] :25350 -> 27 transitions | Saved: transition_list_00266__25350.csv
# [Row 267/12741] P83731:17760 -> 18 transitions | Saved: transition_list_00267_P83731_17760.csv
# [Row 268/12741] :25840 -> 27 transitions | Saved: transition_list_00268__25840.csv
# [Row 269/12741] Q86W42-2:34830 -> 29 transitions | Saved: transition_list_00269_Q86W42-2_34830.csv
# [Row 270/12741] P62750:17550 -> 19 transitions | Saved: transition_list_00270_P62750_17550.csv
# [Row 271/12741] :63950 -> 11 transitions | Saved: transition_list_00271__63950.csv
# [Row 272/12741] Q86U42-1:32680 -> 30 transitions | Saved: transition_list_00272_Q86U42-1_32680.csv
# [Row 273/12741] P10916:18660 -> 20 transitions | Saved: transition_list_00273_P10916_18660.csv
# [Row 274/12741] :65620 -> 10 transitions | Saved: transition_list_00274__65620.csv
# [Row 275/12741] O14949:9770 -> 10 transitions | Saved: transition_list_00275_O14949_9770.csv
# [Row 276/12741] P56385:7800 -> 9 transitions | Saved: transition_list_00276_P56385_7800.csv
# [Row 277/12741] P30086:20980 -> 22 transitions | Saved: transition_list_00277_P30086_20980.csv
# [Row 278/12741] O75489-1:26370 -> 28 transitions | Saved: transition_list_00278_O75489-1_26370.csv
# [Row 279/12741] :60220 -> 13 transitions | Saved: transition_list_00279__60220.csv
# [Row 280/12741] :26680 -> 28 transitions | Saved: transition_list_00280__26680.csv
# [Row 281/12741] Q99735-1:16490 -> 17 transitions | Saved: transition_list_00281_Q99735-1_16490.csv
# [Row 282/12741] :52310 -> 18 transitions | Saved: transition_list_00282__52310.csv
# [Row 283/12741] :23630 -> 25 transitions | Saved: transition_list_00283__23630.csv
# [Row 284/12741] :66790 -> 9 transitions | Saved: transition_list_00284__66790.csv
# [Row 285/12741] P80511:10470 -> 11 transitions | Saved: transition_list_00285_P80511_10470.csv
# [Row 286/12741] P50120:15580 -> 17 transitions | Saved: transition_list_00286_P50120_15580.csv
# [Row 287/12741] :54880 -> 16 transitions | Saved: transition_list_00287__54880.csv
# [Row 288/12741] Q9BTP6:25020 -> 26 transitions | Saved: transition_list_00288_Q9BTP6_25020.csv
# [Row 289/12741] :35580 -> 28 transitions | Saved: transition_list_00289__35580.csv
# [Row 290/12741] :31170 -> 31 transitions | Saved: transition_list_00290__31170.csv
# [Row 291/12741] P00414:29800 -> 31 transitions | Saved: transition_list_00291_P00414_29800.csv
# [Row 292/12741] :31610 -> 31 transitions | Saved: transition_list_00292__31610.csv
# [Row 293/12741] :51160 -> 19 transitions | Saved: transition_list_00293__51160.csv
# [Row 294/12741] Q99497:19990 -> 21 transitions | Saved: transition_list_00294_Q99497_19990.csv
# [Row 295/12741] :53350 -> 17 transitions | Saved: transition_list_00295__53350.csv
# [Row 296/12741] P00338-4:30720 -> 31 transitions | Saved: transition_list_00296_P00338-4_30720.csv
# [Row 297/12741] P30049:15050 -> 16 transitions | Saved: transition_list_00297_P30049_15050.csv
# [Row 298/12741] P63316:18450 -> 19 transitions | Saved: transition_list_00298_P63316_18450.csv
# [Row 299/12741] Q06830:22050 -> 23 transitions | Saved: transition_list_00299_Q06830_22050.csv
# [Row 300/12741] :52580 -> 18 transitions | Saved: transition_list_00300__52580.csv
# [Row 301/12741] P61204-1:20650 -> 22 transitions | Saved: transition_list_00301_P61204-1_20650.csv
# [Row 302/12741] :39070 -> 26 transitions | Saved: transition_list_00302__39070.csv
# [Row 303/12741] :55420 -> 16 transitions | Saved: transition_list_00303__55420.csv
# [Row 304/12741] P00441:15850 -> 17 transitions | Saved: transition_list_00304_P00441_15850.csv
# [Row 305/12741] :33620 -> 29 transitions | Saved: transition_list_00305__33620.csv
# [Row 306/12741] Q8NGC4:35060 -> 29 transitions | Saved: transition_list_00306_Q8NGC4_35060.csv
# [Row 307/12741] :43960 -> 23 transitions | Saved: transition_list_00307__43960.csv
# [Row 308/12741] P07195:36660 -> 28 transitions | Saved: transition_list_00308_P07195_36660.csv
# [Row 309/12741] P35914-2:26970 -> 29 transitions | Saved: transition_list_00309_P35914-2_26970.csv
# [Row 310/12741] :32010 -> 30 transitions | Saved: transition_list_00310__32010.csv
# [Row 311/12741] Q96L08-2:26040 -> 27 transitions | Saved: transition_list_00311_Q96L08-2_26040.csv
# [Row 312/12741] P63267-2:36880 -> 27 transitions | Saved: transition_list_00312_P63267-2_36880.csv
# [Row 313/12741] :53950 -> 17 transitions | Saved: transition_list_00313__53950.csv
# [Row 314/12741] :29570 -> 31 transitions | Saved: transition_list_00314__29570.csv
# [Row 315/12741] P59998-1:19580 -> 20 transitions | Saved: transition_list_00315_P59998-1_19580.csv
# [Row 316/12741] :49150 -> 20 transitions | Saved: transition_list_00316__49150.csv
# [Row 317/12741] P04179-2:18200 -> 19 transitions | Saved: transition_list_00317_P04179-2_18200.csv
# [Row 318/12741] :41310 -> 25 transitions | Saved: transition_list_00318__41310.csv
# [Row 319/12741] :32250 -> 30 transitions | Saved: transition_list_00319__32250.csv
# [Row 320/12741] Q8IV42-2:32890 -> 30 transitions | Saved: transition_list_00320_Q8IV42-2_32890.csv
# [Row 321/12741] :48840 -> 20 transitions | Saved: transition_list_00321__48840.csv
# [Row 322/12741] P19429:23990 -> 25 transitions | Saved: transition_list_00322_P19429_23990.csv
# [Row 323/12741] :50640 -> 19 transitions | Saved: transition_list_00323__50640.csv
# [Row 324/12741] :56330 -> 15 transitions | Saved: transition_list_00324__56330.csv
# [Row 325/12741] :39600 -> 26 transitions | Saved: transition_list_00325__39600.csv
# [Row 326/12741] Q7Z6M3-3:28690 -> 28 transitions | Saved: transition_list_00326_Q7Z6M3-3_28690.csv
# [Row 327/12741] :44460 -> 23 transitions | Saved: transition_list_00327__44460.csv
# [Row 328/12741] :37440 -> 26 transitions | Saved: transition_list_00328__37440.csv
# [Row 329/12741] :48180 -> 20 transitions | Saved: transition_list_00329__48180.csv
# [Row 330/12741] P00403:25640 -> 26 transitions | Saved: transition_list_00330_P00403_25640.csv
# [Row 331/12741] P00568:21660 -> 23 transitions | Saved: transition_list_00331_P00568_21660.csv
# [Row 332/12741] :29130 -> 30 transitions | Saved: transition_list_00332__29130.csv
# [Row 333/12741] Q96QD9-1:35870 -> 27 transitions | Saved: transition_list_00333_Q96QD9-1_35870.csv
# [Row 334/12741] P23284:20360 -> 21 transitions | Saved: transition_list_00334_P23284_20360.csv
# [Row 335/12741] :45110 -> 22 transitions | Saved: transition_list_00335__45110.csv
# [Row 336/12741] P62805:6870 -> 7 transitions | Saved: transition_list_00336_P62805_6870.csv
# [Row 337/12741] Q8WZA0-1:21390 -> 22 transitions | Saved: transition_list_00337_Q8WZA0-1_21390.csv
# [Row 338/12741] P20962:11450 -> 12 transitions | Saved: transition_list_00338_P20962_11450.csv
# [Row 339/12741] :45320 -> 22 transitions | Saved: transition_list_00339__45320.csv
# [Row 340/12741] :58820 -> 14 transitions | Saved: transition_list_00340__58820.csv
# [Row 341/12741] :63550 -> 11 transitions | Saved: transition_list_00341__63550.csv
# [Row 342/12741] P63218:7510 -> 8 transitions | Saved: transition_list_00342_P63218_7510.csv
# [Row 343/12741] :54610 -> 16 transitions | Saved: transition_list_00343__54610.csv
# [Row 344/12741] P19429:24190 -> 25 transitions | Saved: transition_list_00344_P19429_24190.csv
# [Row 345/12741] :65920 -> 9 transitions | Saved: transition_list_00345__65920.csv
# [Row 346/12741] :46400 -> 21 transitions | Saved: transition_list_00346__46400.csv
# [Row 347/12741] :46100 -> 22 transitions | Saved: transition_list_00347__46100.csv
# [Row 348/12741] :63320 -> 11 transitions | Saved: transition_list_00348__63320.csv
# [Row 349/12741] :48500 -> 20 transitions | Saved: transition_list_00349__48500.csv
# [Row 350/12741] :64730 -> 10 transitions | Saved: transition_list_00350__64730.csv
# [Row 351/12741] P55916-1:34320 -> 29 transitions | Saved: transition_list_00351_P55916-1_34320.csv
# [Row 352/12741] Q93077:8270 -> 8 transitions | Saved: transition_list_00352_Q93077_8270.csv
# [Row 353/12741] L0R6Q1-1:11040 -> 12 transitions | Saved: transition_list_00353_L0R6Q1-1_11040.csv
# [Row 354/12741] :27480 -> 27 transitions | Saved: transition_list_00354__27480.csv
# [Row 355/12741] :55980 -> 15 transitions | Saved: transition_list_00355__55980.csv
# [Row 356/12741] Q96KB5-1:36380 -> 28 transitions | Saved: transition_list_00356_Q96KB5-1_36380.csv
# [Row 357/12741] :46890 -> 21 transitions | Saved: transition_list_00357__46890.csv
# [Row 358/12741] :64180 -> 10 transitions | Saved: transition_list_00358__64180.csv
# [Row 359/12741] P09382:14610 -> 15 transitions | Saved: transition_list_00359_P09382_14610.csv
# [Row 360/12741] :62900 -> 11 transitions | Saved: transition_list_00360__62900.csv
# [Row 361/12741] :67880 -> 8 transitions | Saved: transition_list_00361__67880.csv
# [Row 362/12741] :32460 -> 30 transitions | Saved: transition_list_00362__32460.csv
# [Row 363/12741] O43598-1:19130 -> 19 transitions | Saved: transition_list_00363_O43598-1_19130.csv
# [Row 364/12741] :53670 -> 17 transitions | Saved: transition_list_00364__53670.csv
# [Row 365/12741] :49650 -> 19 transitions | Saved: transition_list_00365__49650.csv
# [Row 366/12741] P19429:24560 -> 25 transitions | Saved: transition_list_00366_P19429_24560.csv
# [Row 367/12741] :67060 -> 9 transitions | Saved: transition_list_00367__67060.csv
# [Row 368/12741] Q9Y5N1-3:40730 -> 25 transitions | Saved: transition_list_00368_Q9Y5N1-3_40730.csv
# [Row 369/12741] :39990 -> 25 transitions | Saved: transition_list_00369__39990.csv
# [Row 370/12741] :59180 -> 13 transitions | Saved: transition_list_00370__59180.csv
# [Row 371/12741] P02647:28160 -> 30 transitions | Saved: transition_list_00371_P02647_28160.csv
# [Row 372/12741] P63104-1:27770 -> 29 transitions | Saved: transition_list_00372_P63104-1_27770.csv
# [Row 373/12741] P05067-2:30500 -> 31 transitions | Saved: transition_list_00373_P05067-2_30500.csv
# [Row 374/12741] Q86U42-1:32670 -> 30 transitions | Saved: transition_list_00374_Q86U42-1_32670.csv
# [Row 375/12741] P04792:22710 -> 23 transitions | Saved: transition_list_00375_P04792_22710.csv
# [Row 376/12741] P02144:17050 -> 18 transitions | Saved: transition_list_00376_P02144_17050.csv
# [Row 377/12741] Q01105-1:33310 -> 30 transitions | Saved: transition_list_00377_Q01105-1_33310.csv
# [Row 378/12741] P63316:18530 -> 19 transitions | Saved: transition_list_00378_P63316_18530.csv
# [Row 379/12741] :25350 -> 27 transitions | Saved: transition_list_00379__25350.csv
# [Row 380/12741] :25840 -> 27 transitions | Saved: transition_list_00380__25840.csv
# [Row 381/12741] P09211:23190 -> 24 transitions | Saved: transition_list_00381_P09211_23190.csv
# [Row 382/12741] :30090 -> 32 transitions | Saved: transition_list_00382__30090.csv
# [Row 383/12741] :65620 -> 10 transitions | Saved: transition_list_00383__65620.csv
# [Row 384/12741] :60220 -> 13 transitions | Saved: transition_list_00384__60220.csv
# [Row 385/12741] :63950 -> 11 transitions | Saved: transition_list_00385__63950.csv
# [Row 386/12741] P62750:17550 -> 19 transitions | Saved: transition_list_00386_P62750_17550.csv
# [Row 387/12741] :26680 -> 28 transitions | Saved: transition_list_00387__26680.csv
# [Row 388/12741] P62937-1:17940 -> 19 transitions | Saved: transition_list_00388_P62937-1_17940.csv
# [Row 389/12741] P42766:14370 -> 16 transitions | Saved: transition_list_00389_P42766_14370.csv
# [Row 390/12741] P78310-2:38310 -> 27 transitions | Saved: transition_list_00390_P78310-2_38310.csv
# [Row 391/12741] P50120:15580 -> 17 transitions | Saved: transition_list_00391_P50120_15580.csv
# [Row 392/12741] P56385:7800 -> 9 transitions | Saved: transition_list_00392_P56385_7800.csv
# [Row 393/12741] :34090 -> 29 transitions | Saved: transition_list_00393__34090.csv
# [Row 394/12741] :32010 -> 30 transitions | Saved: transition_list_00394__32010.csv
# [Row 395/12741] O14949:9770 -> 10 transitions | Saved: transition_list_00395_O14949_9770.csv
# [Row 396/12741] :31170 -> 31 transitions | Saved: transition_list_00396__31170.csv
# [Row 397/12741] P00338-4:30720 -> 31 transitions | Saved: transition_list_00397_P00338-4_30720.csv
# [Row 398/12741] Q9BTP6:25020 -> 26 transitions | Saved: transition_list_00398_Q9BTP6_25020.csv
# [Row 399/12741] Q96QD9-1:35870 -> 28 transitions | Saved: transition_list_00399_Q96QD9-1_35870.csv
# [Row 400/12741] :54630 -> 16 transitions | Saved: transition_list_00400__54630.csv
# [Row 401/12741] :64730 -> 10 transitions | Saved: transition_list_00401__64730.csv
# [Row 402/12741] :66790 -> 9 transitions | Saved: transition_list_00402__66790.csv
# [Row 403/12741] :51160 -> 19 transitions | Saved: transition_list_00403__51160.csv
# [Row 404/12741] :54880 -> 16 transitions | Saved: transition_list_00404__54880.csv
# [Row 405/12741] P30086:20980 -> 22 transitions | Saved: transition_list_00405_P30086_20980.csv
# [Row 406/12741] P04179-2:18200 -> 19 transitions | Saved: transition_list_00406_P04179-2_18200.csv
# [Row 407/12741] Q99497:19990 -> 21 transitions | Saved: transition_list_00407_Q99497_19990.csv
# [Row 408/12741] Q99735-1:16490 -> 17 transitions | Saved: transition_list_00408_Q99735-1_16490.csv
# [Row 409/12741] P62805:7590 -> 8 transitions | Saved: transition_list_00409_P62805_7590.csv
# [Row 410/12741] :45110 -> 22 transitions | Saved: transition_list_00410__45110.csv
# [Row 411/12741] P00414:29800 -> 31 transitions | Saved: transition_list_00411_P00414_29800.csv
# [Row 412/12741] Q96KB5-1:36370 -> 28 transitions | Saved: transition_list_00412_Q96KB5-1_36370.csv
# [Row 413/12741] P09210:25570 -> 27 transitions | Saved: transition_list_00413_P09210_25570.csv
# [Row 414/12741] P00568:21660 -> 23 transitions | Saved: transition_list_00414_P00568_21660.csv
# [Row 415/12741] O75489-1:26370 -> 28 transitions | Saved: transition_list_00415_O75489-1_26370.csv
# [Row 416/12741] :53350 -> 17 transitions | Saved: transition_list_00416__53350.csv
# [Row 417/12741] :37440 -> 27 transitions | Saved: transition_list_00417__37440.csv
# [Row 418/12741] P16104:15050 -> 16 transitions | Saved: transition_list_00418_P16104_15050.csv
# [Row 419/12741] P61204-1:20650 -> 22 transitions | Saved: transition_list_00419_P61204-1_20650.csv
# [Row 420/12741] :35580 -> 28 transitions | Saved: transition_list_00420__35580.csv
# [Row 421/12741] :46100 -> 22 transitions | Saved: transition_list_00421__46100.csv
# [Row 422/12741] P04792:23440 -> 25 transitions | Saved: transition_list_00422_P04792_23440.csv
# [Row 423/12741] :38880 -> 26 transitions | Saved: transition_list_00423__38880.csv
# [Row 424/12741] :46400 -> 21 transitions | Saved: transition_list_00424__46400.csv
# [Row 425/12741] Q93077:8270 -> 8 transitions | Saved: transition_list_00425_Q93077_8270.csv
# [Row 426/12741] :49150 -> 20 transitions | Saved: transition_list_00426__49150.csv
# [Row 427/12741] :58820 -> 14 transitions | Saved: transition_list_00427__58820.csv
# [Row 428/12741] :44460 -> 23 transitions | Saved: transition_list_00428__44460.csv
# [Row 429/12741] :50640 -> 19 transitions | Saved: transition_list_00429__50640.csv
# [Row 430/12741] Q86W42-2:34830 -> 29 transitions | Saved: transition_list_00430_Q86W42-2_34830.csv
# [Row 431/12741] Q7Z6M3-3:28690 -> 30 transitions | Saved: transition_list_00431_Q7Z6M3-3_28690.csv
# [Row 432/12741] :62920 -> 11 transitions | Saved: transition_list_00432__62920.csv
# [Row 433/12741] O14618:29050 -> 30 transitions | Saved: transition_list_00433_O14618_29050.csv
# [Row 434/12741] :56330 -> 15 transitions | Saved: transition_list_00434__56330.csv
# [Row 435/12741] :43530 -> 23 transitions | Saved: transition_list_00435__43530.csv
# [Row 436/12741] :55420 -> 16 transitions | Saved: transition_list_00436__55420.csv
# [Row 437/12741] :29570 -> 31 transitions | Saved: transition_list_00437__29570.csv
# [Row 438/12741] :48840 -> 20 transitions | Saved: transition_list_00438__48840.csv
# [Row 439/12741] Q8N0Y2-2:35230 -> 28 transitions | Saved: transition_list_00439_Q8N0Y2-2_35230.csv
# [Row 440/12741] P19429:24390 -> 25 transitions | Saved: transition_list_00440_P19429_24390.csv
# [Row 441/12741] :50060 -> 19 transitions | Saved: transition_list_00441__50060.csv
# [Row 442/12741] :31610 -> 31 transitions | Saved: transition_list_00442__31610.csv
# [Row 443/12741] :51890 -> 18 transitions | Saved: transition_list_00443__51890.csv
# [Row 444/12741] :41300 -> 25 transitions | Saved: transition_list_00444__41300.csv
# [Row 445/12741] P00441:15850 -> 17 transitions | Saved: transition_list_00445_P00441_15850.csv
# [Row 446/12741] :48500 -> 20 transitions | Saved: transition_list_00446__48500.csv
# [Row 447/12741] P20962:11450 -> 12 transitions | Saved: transition_list_00447_P20962_11450.csv
# [Row 448/12741] P07195:36660 -> 28 transitions | Saved: transition_list_00448_P07195_36660.csv
# [Row 449/12741] :44740 -> 23 transitions | Saved: transition_list_00449__44740.csv
# [Row 450/12741] :60960 -> 12 transitions | Saved: transition_list_00450__60960.csv
# [Row 451/12741] :55980 -> 15 transitions | Saved: transition_list_00451__55980.csv
# [Row 452/12741] P68871:11860 -> 11 transitions | Saved: transition_list_00452_P68871_11860.csv
# [Row 453/12741] :67030 -> 9 transitions | Saved: transition_list_00453__67030.csv
# [Row 454/12741] O75348:13680 -> 14 transitions | Saved: transition_list_00454_O75348_13680.csv
# [Row 455/12741] :29360 -> 30 transitions | Saved: transition_list_00455__29360.csv
# [Row 456/12741] :52300 -> 18 transitions | Saved: transition_list_00456__52300.csv
# [Row 457/12741] :59780 -> 13 transitions | Saved: transition_list_00457__59780.csv
# [Row 458/12741] P19429:23990 -> 25 transitions | Saved: transition_list_00458_P19429_23990.csv
# [Row 459/12741] :64180 -> 10 transitions | Saved: transition_list_00459__64180.csv
# [Row 460/12741] :34350 -> 29 transitions | Saved: transition_list_00460__34350.csv
# [Row 461/12741] :48180 -> 20 transitions | Saved: transition_list_00461__48180.csv
# [Row 462/12741] :63550 -> 11 transitions | Saved: transition_list_00462__63550.csv
# [Row 463/12741] :71050 -> 6 transitions | Saved: transition_list_00463__71050.csv
# [Row 464/12741] :27480 -> 28 transitions | Saved: transition_list_00464__27480.csv
# [Row 465/12741] :43960 -> 23 transitions | Saved: transition_list_00465__43960.csv
# [Row 466/12741] :57080 -> 15 transitions | Saved: transition_list_00466__57080.csv
# [Row 467/12741] :63170 -> 11 transitions | Saved: transition_list_00467__63170.csv
# [Row 468/12741] P35914-2:27020 -> 29 transitions | Saved: transition_list_00468_P35914-2_27020.csv
# [Row 469/12741] :32460 -> 30 transitions | Saved: transition_list_00469__32460.csv
# [Row 470/12741] P06703:10390 -> 11 transitions | Saved: transition_list_00470_P06703_10390.csv
# [Row 471/12741] :49770 -> 19 transitions | Saved: transition_list_00471__49770.csv
# [Row 472/12741] :69630 -> 7 transitions | Saved: transition_list_00472__69630.csv
# [Row 473/12741] P19429:24190 -> 25 transitions | Saved: transition_list_00473_P19429_24190.csv
# [Row 474/12741] :65920 -> 9 transitions | Saved: transition_list_00474__65920.csv
# [Row 475/12741] P35268:14650 -> 14 transitions | Saved: transition_list_00475_P35268_14650.csv
# [Row 476/12741] Q16777:13880 -> 15 transitions | Saved: transition_list_00476_Q16777_13880.csv
# [Row 477/12741] O75438-1:6830 -> 7 transitions | Saved: transition_list_00477_O75438-1_6830.csv
# [Row 478/12741] P05109:10830 -> 12 transitions | Saved: transition_list_00478_P05109_10830.csv
# [Row 479/12741] Q15847:7750 -> 8 transitions | Saved: transition_list_00479_Q15847_7750.csv
# [Row 480/12741] :28410 -> 27 transitions | Saved: transition_list_00480__28410.csv
# [Row 481/12741] P50461-1:21010 -> 14 transitions | Saved: transition_list_00481_P50461-1_21010.csv
# [Row 482/12741] P00338-4:30260 -> 27 transitions | Saved: transition_list_00482_P00338-4_30260.csv
# [Row 483/12741] :54490 -> 15 transitions | Saved: transition_list_00483__54490.csv
# [Row 484/12741] P62805:11350 -> 11 transitions | Saved: transition_list_00484_P62805_11350.csv
# [Row 485/12741] :39150 -> 19 transitions | Saved: transition_list_00485__39150.csv
# [Row 486/12741] P60174-1:26550 -> 19 transitions | Saved: transition_list_00486_P60174-1_26550.csv
# [Row 487/12741] P62807:13780 -> 13 transitions | Saved: transition_list_00487_P62807_13780.csv
# [Row 488/12741] :27170 -> 22 transitions | Saved: transition_list_00488__27170.csv
# [Row 489/12741] P30048-1:21570 -> 19 transitions | Saved: transition_list_00489_P30048-1_21570.csv
# [Row 490/12741] P45379-9:31480 -> 14 transitions | Saved: transition_list_00490_P45379-9_31480.csv
# [Row 491/12741] :21260 -> 17 transitions | Saved: transition_list_00491__21260.csv
# [Row 492/12741] Q16777:5410 -> 4 transitions | Saved: transition_list_00492_Q16777_5410.csv
# [Row 493/12741] :43930 -> 18 transitions | Saved: transition_list_00493__43930.csv
# [Row 494/12741] :64400 -> 10 transitions | Saved: transition_list_00494__64400.csv
# [Row 495/12741] :43070 -> 17 transitions | Saved: transition_list_00495__43070.csv
# [Row 496/12741] :59260 -> 11 transitions | Saved: transition_list_00496__59260.csv
# [Row 497/12741] :62950 -> 10 transitions | Saved: transition_list_00497__62950.csv
# [Row 498/12741] :56540 -> 13 transitions | Saved: transition_list_00498__56540.csv
# [Row 499/12741] :29630 -> 21 transitions | Saved: transition_list_00499__29630.csv
# [Row 500/12741] :58380 -> 12 transitions | Saved: transition_list_00500__58380.csv
# [Row 501/12741] :24370 -> 19 transitions | Saved: transition_list_00501__24370.csv
# [Row 502/12741] P30086:20030 -> 14 transitions | Saved: transition_list_00502_P30086_20030.csv
# [Row 503/12741] P06703:10090 -> 8 transitions | Saved: transition_list_00503_P06703_10090.csv
# [Row 504/12741] :34760 -> 19 transitions | Saved: transition_list_00504__34760.csv
# [Row 505/12741] :29950 -> 23 transitions | Saved: transition_list_00505__29950.csv
# [Row 506/12741] P24539:24700 -> 18 transitions | Saved: transition_list_00506_P24539_24700.csv
# [Row 507/12741] P06454-2:11980 -> 11 transitions | Saved: transition_list_00507_P06454-2_11980.csv
# [Row 508/12741] :36080 -> 16 transitions | Saved: transition_list_00508__36080.csv
# [Row 509/12741] :65890 -> 9 transitions | Saved: transition_list_00509__65890.csv
# [Row 510/12741] :39850 -> 15 transitions | Saved: transition_list_00510__39850.csv
# [Row 511/12741] :54170 -> 15 transitions | Saved: transition_list_00511__54170.csv
# [Row 512/12741] :45230 -> 17 transitions | Saved: transition_list_00512__45230.csv
# [Row 513/12741] P08590:21960 -> 14 transitions | Saved: transition_list_00513_P08590_21960.csv
# [Row 514/12741] P55916-1:34250 -> 22 transitions | Saved: transition_list_00514_P55916-1_34250.csv
# [Row 515/12741] :42710 -> 16 transitions | Saved: transition_list_00515__42710.csv
# [Row 516/12741] P10412:8490 -> 7 transitions | Saved: transition_list_00516_P10412_8490.csv
# [Row 517/12741] :53340 -> 14 transitions | Saved: transition_list_00517__53340.csv
# [Row 518/12741] P09211:23190 -> 20 transitions | Saved: transition_list_00518_P09211_23190.csv
# [Row 519/12741] :57090 -> 12 transitions | Saved: transition_list_00519__57090.csv
# [Row 520/12741] :40790 -> 13 transitions | Saved: transition_list_00520__40790.csv
# [Row 521/12741] :61890 -> 12 transitions | Saved: transition_list_00521__61890.csv
# [Row 522/12741] P69905:15570 -> 11 transitions | Saved: transition_list_00522_P69905_15570.csv
# [Row 523/12741] :57940 -> 10 transitions | Saved: transition_list_00523__57940.csv
# [Row 524/12741] :27720 -> 18 transitions | Saved: transition_list_00524__27720.csv
# [Row 525/12741] :40580 -> 19 transitions | Saved: transition_list_00525__40580.csv
# [Row 526/12741] :29380 -> 23 transitions | Saved: transition_list_00526__29380.csv
# [Row 527/12741] :18040 -> 14 transitions | Saved: transition_list_00527__18040.csv
# [Row 528/12741] :28620 -> 16 transitions | Saved: transition_list_00528__28620.csv
# [Row 529/12741] P14927-1:13460 -> 8 transitions | Saved: transition_list_00529_P14927-1_13460.csv
# [Row 530/12741] :29020 -> 18 transitions | Saved: transition_list_00530__29020.csv
# [Row 531/12741] Q9Y281-1:18620 -> 12 transitions | Saved: transition_list_00531_Q9Y281-1_18620.csv
# [Row 532/12741] :49810 -> 13 transitions | Saved: transition_list_00532__49810.csv
# [Row 533/12741] :25050 -> 14 transitions | Saved: transition_list_00533__25050.csv
# [Row 534/12741] Q01995:22510 -> 12 transitions | Saved: transition_list_00534_Q01995_22510.csv
# [Row 535/12741] P80511:10440 -> 6 transitions | Saved: transition_list_00535_P80511_10440.csv
# [Row 536/12741] :32040 -> 19 transitions | Saved: transition_list_00536__32040.csv
# [Row 537/12741] P42766:14460 -> 11 transitions | Saved: transition_list_00537_P42766_14460.csv
# [Row 538/12741] :46590 -> 14 transitions | Saved: transition_list_00538__46590.csv
# [Row 539/12741] :62260 -> 11 transitions | Saved: transition_list_00539__62260.csv
# [Row 540/12741] :71010 -> 6 transitions | Saved: transition_list_00540__71010.csv
# [Row 541/12741] :25810 -> 15 transitions | Saved: transition_list_00541__25810.csv
# ...
# [Row 12571/12741] P00568:21630 -> 21 transitions | Saved: transition_list_12571_P00568_21630.csv
# [Row 12572/12741] P62937-1:17890 -> 16 transitions | Saved: transition_list_12572_P62937-1_17890.csv
# [Row 12573/12741] P45379-12:30800 -> 30 transitions | Saved: transition_list_12573_P45379-12_30800.csv
# [Row 12574/12741] :26920 -> 25 transitions | Saved: transition_list_12574__26920.csv
# [Row 12575/12741] :22430 -> 23 transitions | Saved: transition_list_12575__22430.csv
# [Row 12576/12741] P05976-1:21360 -> 20 transitions | Saved: transition_list_12576_P05976-1_21360.csv
# [Row 12577/12741] P63104-1:27720 -> 25 transitions | Saved: transition_list_12577_P63104-1_27720.csv
# [Row 12578/12741] P23284:20350 -> 19 transitions | Saved: transition_list_12578_P23284_20350.csv
# [Row 12579/12741] P02144:17110 -> 15 transitions | Saved: transition_list_12579_P02144_17110.csv
# [Row 12580/12741] P02647:27990 -> 26 transitions | Saved: transition_list_12580_P02647_27990.csv
# [Row 12581/12741] P09210:25750 -> 26 transitions | Saved: transition_list_12581_P09210_25750.csv
# [Row 12582/12741] Q9BQY9-4:28950 -> 27 transitions | Saved: transition_list_12582_Q9BQY9-4_28950.csv
# [Row 12583/12741] O14950:19650 -> 20 transitions | Saved: transition_list_12583_O14950_19650.csv
# [Row 12584/12741] O15212:14490 -> 13 transitions | Saved: transition_list_12584_O15212_14490.csv
# [Row 12585/12741] O43567-2:29590 -> 28 transitions | Saved: transition_list_12585_O43567-2_29590.csv
# [Row 12586/12741] P07737:14980 -> 14 transitions | Saved: transition_list_12586_P07737_14980.csv
# [Row 12587/12741] :25150 -> 25 transitions | Saved: transition_list_12587__25150.csv
# [Row 12588/12741] O43598-1:19130 -> 18 transitions | Saved: transition_list_12588_O43598-1_19130.csv
# [Row 12589/12741] P19404:23820 -> 22 transitions | Saved: transition_list_12589_P19404_23820.csv
# [Row 12590/12741] P09210:25500 -> 23 transitions | Saved: transition_list_12590_P09210_25500.csv
# [Row 12591/12741] O14949:9770 -> 8 transitions | Saved: transition_list_12591_O14949_9770.csv
# [Row 12592/12741] P30086:20950 -> 19 transitions | Saved: transition_list_12592_P30086_20950.csv
# [Row 12593/12741] P68871:16170 -> 14 transitions | Saved: transition_list_12593_P68871_16170.csv
# [Row 12594/12741] P24310:6760 -> 7 transitions | Saved: transition_list_12594_P24310_6760.csv
# [Row 12595/12741] P62857:7860 -> 8 transitions | Saved: transition_list_12595_P62857_7860.csv
# [Row 12596/12741] Q9BTM1:13940 -> 14 transitions | Saved: transition_list_12596_Q9BTM1_13940.csv
# [Row 12597/12741] P25815:10400 -> 10 transitions | Saved: transition_list_12597_P25815_10400.csv
# [Row 12598/12741] P62854:12850 -> 12 transitions | Saved: transition_list_12598_P62854_12850.csv
# [Row 12599/12741] O43677:5930 -> 5 transitions | Saved: transition_list_12599_O43677_5930.csv
# [Row 12600/12741] P60174-1:27280 -> 23 transitions | Saved: transition_list_12600_P60174-1_27280.csv
# [Row 12601/12741] P68871:16520 -> 16 transitions | Saved: transition_list_12601_P68871_16520.csv
# [Row 12602/12741] P62269:17630 -> 16 transitions | Saved: transition_list_12602_P62269_17630.csv
# [Row 12603/12741] P69905:15400 -> 12 transitions | Saved: transition_list_12603_P69905_15400.csv
# [Row 12604/12741] :33230 -> 26 transitions | Saved: transition_list_12604__33230.csv
# [Row 12605/12741] O95167:9210 -> 9 transitions | Saved: transition_list_12605_O95167_9210.csv
# [Row 12606/12741] :28470 -> 25 transitions | Saved: transition_list_12606__28470.csv
# [Row 12607/12741] Q86W42-2:34810 -> 23 transitions | Saved: transition_list_12607_Q86W42-2_34810.csv
# [Row 12608/12741] :32040 -> 24 transitions | Saved: transition_list_12608__32040.csv
# [Row 12609/12741] P19429:24030 -> 21 transitions | Saved: transition_list_12609_P19429_24030.csv
# [Row 12610/12741] :53370 -> 13 transitions | Saved: transition_list_12610__53370.csv
# [Row 12611/12741] P10412:8500 -> 7 transitions | Saved: transition_list_12611_P10412_8500.csv
# [Row 12612/12741] P0DP23:16790 -> 16 transitions | Saved: transition_list_12612_P0DP23_16790.csv
# [Row 12613/12741] P30043:22000 -> 19 transitions | Saved: transition_list_12613_P30043_22000.csv
# [Row 12614/12741] :59310 -> 7 transitions | Saved: transition_list_12614__59310.csv
# [Row 12615/12741] :31660 -> 25 transitions | Saved: transition_list_12615__31660.csv
# [Row 12616/12741] P18085:20560 -> 18 transitions | Saved: transition_list_12616_P18085_20560.csv
# [Row 12617/12741] :26720 -> 22 transitions | Saved: transition_list_12617__26720.csv
# [Row 12618/12741] P05067-2:30480 -> 26 transitions | Saved: transition_list_12618_P05067-2_30480.csv
# [Row 12619/12741] :49820 -> 14 transitions | Saved: transition_list_12619__49820.csv
# [Row 12620/12741] :40330 -> 18 transitions | Saved: transition_list_12620__40330.csv
# [Row 12621/12741] :13060 -> 11 transitions | Saved: transition_list_12621__13060.csv
# [Row 12622/12741] :52210 -> 11 transitions | Saved: transition_list_12622__52210.csv
# [Row 12623/12741] P26678:6150 -> 6 transitions | Saved: transition_list_12623_P26678_6150.csv
# [Row 12624/12741] :55760 -> 9 transitions | Saved: transition_list_12624__55760.csv
# [Row 12625/12741] Q5TGZ0-1:8730 -> 8 transitions | Saved: transition_list_12625_Q5TGZ0-1_8730.csv
# [Row 12626/12741] P62280:18360 -> 17 transitions | Saved: transition_list_12626_P62280_18360.csv
# [Row 12627/12741] O95563:14210 -> 12 transitions | Saved: transition_list_12627_O95563_14210.csv
# [Row 12628/12741] :36780 -> 18 transitions | Saved: transition_list_12628__36780.csv
# [Row 12629/12741] :34400 -> 19 transitions | Saved: transition_list_12629__34400.csv
# [Row 12630/12741] :41530 -> 18 transitions | Saved: transition_list_12630__41530.csv
# [Row 12631/12741] :48650 -> 14 transitions | Saved: transition_list_12631__48650.csv
# [Row 12632/12741] P09493-1:32740 -> 22 transitions | Saved: transition_list_12632_P09493-1_32740.csv
# [Row 12633/12741] :46280 -> 16 transitions | Saved: transition_list_12633__46280.csv
# [Row 12634/12741] Q02221:9470 -> 9 transitions | Saved: transition_list_12634_Q02221_9470.csv
# [Row 12635/12741] Q9HD34:10680 -> 4 transitions | Saved: transition_list_12635_Q9HD34_10680.csv
# [Row 12636/12741] Q86Y39-1:14690 -> 11 transitions | Saved: transition_list_12636_Q86Y39-1_14690.csv
# [Row 12637/12741] :43880 -> 16 transitions | Saved: transition_list_12637__43880.csv
# [Row 12638/12741] :45070 -> 13 transitions | Saved: transition_list_12638__45070.csv
# [Row 12639/12741] P63316:18600 -> 16 transitions | Saved: transition_list_12639_P63316_18600.csv
# [Row 12640/12741] :39160 -> 13 transitions | Saved: transition_list_12640__39160.csv
# [Row 12641/12741] P61353:15700 -> 13 transitions | Saved: transition_list_12641_P61353_15700.csv
# [Row 12642/12741] :58110 -> 5 transitions | Saved: transition_list_12642__58110.csv
# [Row 12643/12741] P20292:18120 -> 16 transitions | Saved: transition_list_12643_P20292_18120.csv
# [Row 12644/12741] :56960 -> 7 transitions | Saved: transition_list_12644__56960.csv
# [Row 12645/12741] :35600 -> 17 transitions | Saved: transition_list_12645__35600.csv
# [Row 12646/12741] :51000 -> 12 transitions | Saved: transition_list_12646__51000.csv
# [Row 12647/12741] P14927-1:13550 -> 10 transitions | Saved: transition_list_12647_P14927-1_13550.csv
# [Row 12648/12741] O43920:12390 -> 11 transitions | Saved: transition_list_12648_O43920_12390.csv
# [Row 12649/12741] P02647:28140 -> 27 transitions | Saved: transition_list_12649_P02647_28140.csv
# [Row 12650/12741] P04792:23400 -> 19 transitions | Saved: transition_list_12650_P04792_23400.csv
# [Row 12651/12741] P00846:24780 -> 24 transitions | Saved: transition_list_12651_P00846_24780.csv
# [Row 12652/12741] :29970 -> 27 transitions | Saved: transition_list_12652__29970.csv
# [Row 12653/12741] Q9NZD4:11750 -> 10 transitions | Saved: transition_list_12653_Q9NZD4_11750.csv
# [Row 12654/12741] Q16740:30200 -> 28 transitions | Saved: transition_list_12654_Q16740_30200.csv
# [Row 12655/12741] :29220 -> 25 transitions | Saved: transition_list_12655__29220.csv
# [Row 12656/12741] P23284:20350 -> 20 transitions | Saved: transition_list_12656_P23284_20350.csv
# [Row 12657/12741] P37802-1:22330 -> 21 transitions | Saved: transition_list_12657_P37802-1_22330.csv
# [Row 12658/12741] P09210:25750 -> 24 transitions | Saved: transition_list_12658_P09210_25750.csv
# [Row 12659/12741] P04792:22790 -> 22 transitions | Saved: transition_list_12659_P04792_22790.csv
# [Row 12660/12741] P10412:7850 -> 8 transitions | Saved: transition_list_12660_P10412_7850.csv
# [Row 12661/12741] P45379-12:30800 -> 24 transitions | Saved: transition_list_12661_P45379-12_30800.csv
# [Row 12662/12741] Q8WZA0-1:21370 -> 18 transitions | Saved: transition_list_12662_Q8WZA0-1_21370.csv
# [Row 12663/12741] P19429:24560 -> 23 transitions | Saved: transition_list_12663_P19429_24560.csv
# [Row 12664/12741] :25150 -> 22 transitions | Saved: transition_list_12664__25150.csv
# [Row 12665/12741] Q5TGZ0-1:8730 -> 8 transitions | Saved: transition_list_12665_Q5TGZ0-1_8730.csv
# [Row 12666/12741] L0R6Q1-1:11050 -> 11 transitions | Saved: transition_list_12666_L0R6Q1-1_11050.csv
# [Row 12667/12741] :26120 -> 24 transitions | Saved: transition_list_12667__26120.csv
# [Row 12668/12741] :31300 -> 27 transitions | Saved: transition_list_12668__31300.csv
# [Row 12669/12741] P23528:19280 -> 17 transitions | Saved: transition_list_12669_P23528_19280.csv
# [Row 12670/12741] :26940 -> 23 transitions | Saved: transition_list_12670__26940.csv
# [Row 12671/12741] P32119-1:21770 -> 19 transitions | Saved: transition_list_12671_P32119-1_21770.csv
# [Row 12672/12741] :29590 -> 25 transitions | Saved: transition_list_12672__29590.csv
# [Row 12673/12741] :23820 -> 19 transitions | Saved: transition_list_12673__23820.csv
# [Row 12674/12741] P62854:12850 -> 11 transitions | Saved: transition_list_12674_P62854_12850.csv
# [Row 12675/12741] P62937-1:17890 -> 13 transitions | Saved: transition_list_12675_P62937-1_17890.csv
# [Row 12676/12741] P60174-1:26660 -> 24 transitions | Saved: transition_list_12676_P60174-1_26660.csv
# [Row 12677/12741] P07737:14980 -> 9 transitions | Saved: transition_list_12677_P07737_14980.csv
# [Row 12678/12741] O75489-1:26400 -> 23 transitions | Saved: transition_list_12678_O75489-1_26400.csv
# [Row 12679/12741] P63104-1:27750 -> 25 transitions | Saved: transition_list_12679_P63104-1_27750.csv
# [Row 12680/12741] O43768-1:13330 -> 10 transitions | Saved: transition_list_12680_O43768-1_13330.csv
# [Row 12681/12741] :25370 -> 22 transitions | Saved: transition_list_12681__25370.csv
# [Row 12682/12741] :28590 -> 21 transitions | Saved: transition_list_12682__28590.csv
# [Row 12683/12741] O95167:9210 -> 9 transitions | Saved: transition_list_12683_O95167_9210.csv
# [Row 12684/12741] O15212:14490 -> 13 transitions | Saved: transition_list_12684_O15212_14490.csv
# [Row 12685/12741] O43677:5930 -> 5 transitions | Saved: transition_list_12685_O43677_5930.csv
# [Row 12686/12741] P19105:19650 -> 15 transitions | Saved: transition_list_12686_P19105_19650.csv
# [Row 12687/12741] Q9BQY9-4:28950 -> 25 transitions | Saved: transition_list_12687_Q9BQY9-4_28950.csv
# [Row 12688/12741] P30086:20950 -> 14 transitions | Saved: transition_list_12688_P30086_20950.csv
# [Row 12689/12741] P0DP23:16790 -> 16 transitions | Saved: transition_list_12689_P0DP23_16790.csv
# [Row 12690/12741] :30600 -> 25 transitions | Saved: transition_list_12690__30600.csv
# [Row 12691/12741] P49773:13690 -> 12 transitions | Saved: transition_list_12691_P49773_13690.csv
# [Row 12692/12741] P60174-1:27290 -> 22 transitions | Saved: transition_list_12692_P60174-1_27290.csv
# [Row 12693/12741] Q9NRQ5:6770 -> 6 transitions | Saved: transition_list_12693_Q9NRQ5_6770.csv
# [Row 12694/12741] :31660 -> 23 transitions | Saved: transition_list_12694__31660.csv
# [Row 12695/12741] :32000 -> 22 transitions | Saved: transition_list_12695__32000.csv
# [Row 12696/12741] P63316:18580 -> 15 transitions | Saved: transition_list_12696_P63316_18580.csv
# [Row 12697/12741] :33250 -> 22 transitions | Saved: transition_list_12697__33250.csv
# [Row 12698/12741] P69905:15400 -> 10 transitions | Saved: transition_list_12698_P69905_15400.csv
# [Row 12699/12741] P30043:22000 -> 17 transitions | Saved: transition_list_12699_P30043_22000.csv
# [Row 12700/12741] :55750 -> 8 transitions | Saved: transition_list_12700__55750.csv
# [Row 12701/12741] Q16777:5510 -> 5 transitions | Saved: transition_list_12701_Q16777_5510.csv
# [Row 12702/12741] P80511:10420 -> 8 transitions | Saved: transition_list_12702_P80511_10420.csv
# [Row 12703/12741] Q9BTM1:13940 -> 12 transitions | Saved: transition_list_12703_Q9BTM1_13940.csv
# [Row 12704/12741] :28340 -> 23 transitions | Saved: transition_list_12704__28340.csv
# [Row 12705/12741] P62277:17110 -> 8 transitions | Saved: transition_list_12705_P62277_17110.csv
# [Row 12706/12741] P19429:24030 -> 18 transitions | Saved: transition_list_12706_P19429_24030.csv
# [Row 12707/12741] P18085:20560 -> 15 transitions | Saved: transition_list_12707_P18085_20560.csv
# [Row 12708/12741] P46783:18950 -> 16 transitions | Saved: transition_list_12708_P46783_18950.csv
# [Row 12709/12741] :18260 -> 13 transitions | Saved: transition_list_12709__18260.csv
# [Row 12710/12741] :59320 -> 5 transitions | Saved: transition_list_12710__59320.csv
# [Row 12711/12741] P10620-1:17440 -> 13 transitions | Saved: transition_list_12711_P10620-1_17440.csv
# [Row 12712/12741] P68871:16000 -> 11 transitions | Saved: transition_list_12712_P68871_16000.csv
# [Row 12713/12741] :33760 -> 22 transitions | Saved: transition_list_12713__33760.csv
# [Row 12714/12741] P68871:16520 -> 10 transitions | Saved: transition_list_12714_P68871_16520.csv
# [Row 12715/12741] O14949:9770 -> 5 transitions | Saved: transition_list_12715_O14949_9770.csv
# [Row 12716/12741] :49820 -> 11 transitions | Saved: transition_list_12716__49820.csv
# [Row 12717/12741] :43900 -> 9 transitions | Saved: transition_list_12717__43900.csv
# [Row 12718/12741] :40340 -> 13 transitions | Saved: transition_list_12718__40340.csv
# [Row 12719/12741] :27540 -> 17 transitions | Saved: transition_list_12719__27540.csv
# [Row 12720/12741] :36780 -> 17 transitions | Saved: transition_list_12720__36780.csv
# [Row 12721/12741] :47460 -> 8 transitions | Saved: transition_list_12721__47460.csv
# [Row 12722/12741] :54580 -> 5 transitions | Saved: transition_list_12722__54580.csv
# [Row 12723/12741] :51020 -> 8 transitions | Saved: transition_list_12723__51020.csv
# [Row 12724/12741] :52210 -> 7 transitions | Saved: transition_list_12724__52210.csv
# [Row 12725/12741] :13050 -> 8 transitions | Saved: transition_list_12725__13050.csv
# [Row 12726/12741] :34410 -> 17 transitions | Saved: transition_list_12726__34410.csv
# [Row 12727/12741] :35590 -> 13 transitions | Saved: transition_list_12727__35590.csv
# [Row 12728/12741] :46270 -> 7 transitions | Saved: transition_list_12728__46270.csv
# [Row 12729/12741] :32600 -> 17 transitions | Saved: transition_list_12729__32600.csv
# [Row 12730/12741] P68871:16300 -> 8 transitions | Saved: transition_list_12730_P68871_16300.csv
# [Row 12731/12741] Q02221:9490 -> 6 transitions | Saved: transition_list_12731_Q02221_9490.csv
# [Row 12732/12741] :39150 -> 7 transitions | Saved: transition_list_12732__39150.csv
# [Row 12733/12741] :45090 -> 7 transitions | Saved: transition_list_12733__45090.csv
# [Row 12734/12741] :48650 -> 7 transitions | Saved: transition_list_12734__48650.csv
# [Row 12735/12741] :53390 -> 4 transitions | Saved: transition_list_12735__53390.csv
# [Row 12736/12741] P02792:19960 -> 11 transitions | Saved: transition_list_12736_P02792_19960.csv
# [Row 12737/12741] Q08AG7:8370 -> 4 transitions | Saved: transition_list_12737_Q08AG7_8370.csv
# [Row 12738/12741] Q01995:22540 -> 13 transitions | Saved: transition_list_12738_Q01995_22540.csv
# [Row 12739/12741] P68431:12590 -> 6 transitions | Saved: transition_list_12739_P68431_12590.csv
# [Row 12740/12741] :42710 -> 7 transitions | Saved: transition_list_12740__42710.csv
# [Row 12741/12741] Q86W42-2:34820 -> 14 transitions | Saved: transition_list_12741_Q86W42-2_34820.csv
#
# All done. Total transitions across 12741 rows: 216798
# Output folder → F:\tissue\transitions

# %% [markdown]
# plotting smooth XICs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from pathlib import Path

# ---------------- CONFIG ----------------
INPUT_FILE = r"F:/test.xlsx"   # your Excel file
SHEET_NAME = 0
SMOOTH_WINDOW = 100
POLY_ORDER = 1
OUT_PNG = Path(INPUT_FILE).with_name("Book1_no_legend.png")
# ----------------------------------------

# Load and clean data
df = pd.read_excel(INPUT_FILE, sheet_name=SHEET_NAME).dropna(how="all")
df = df.apply(pd.to_numeric, errors="coerce")
df = df.dropna(how="all")

x = df.iloc[:, 0].values
intensity_cols = df.columns[1:]

plt.figure(figsize=(10, 6))
#plt.title("Smoothed Intensity vs Retention Time", fontsize=14)
plt.xlabel("Retention Time", fontsize=12)
plt.ylabel("Intensity (a.u.)", fontsize=12)

for col in intensity_cols:
    y = df[col].values
    if len(y) < SMOOTH_WINDOW:
        smooth_y = y
    else:
        smooth_y = savgol_filter(y, SMOOTH_WINDOW, POLY_ORDER)
    plt.plot(x, smooth_y, linewidth=2, alpha=0.9)

plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(OUT_PNG, dpi=300)
plt.xlim((10,40))
plt.show()

print(f"✅ Plot saved to: {OUT_PNG}")
# Out:
# ✅ Plot saved to: F:\Book1_no_legend.png

# %% [markdown]
# Gaussian distribution

# %%
# AUC (RT window) by charge state + Gaussian fit OVER SCATTERED DATA — single notebook cell
# - Computes AUC per charge in the given RT window
# - Fits a Gaussian to (charge -> AUC)
# - Plots the data points (scatter) and overlays the Gaussian curve on top

import re
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ========= CONFIG =========
FILE_PATH   = Path(r"F:/13970.xlsx")   # <- change if needed
SHEET_NAME  = 0                                    # sheet index or name
RT_WINDOW   = (25.0, 26.0)                         # minutes (min_inclusive, max_inclusive)
OUT_DIR     = Path(r"F:/binary/final")             # <- change if needed
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_CSV     = OUT_DIR / "auc_by_charge_20_25.csv"
OUT_PNG     = OUT_DIR / "charge_envelope_gaussian_over_data.png"
# ==========================

# --- Load Excel ---
df = pd.read_excel(FILE_PATH, sheet_name=SHEET_NAME)

# If first row holds descriptors (Retention Time / Intensity), drop it
if (
    len(df.columns) > 0
    and str(df.columns[0]).lower().startswith("unnamed")
    and isinstance(df.iloc[0, 0], str)
    and "retention" in df.iloc[0, 0].lower()
):
    df = df.iloc[1:].reset_index(drop=True)

# Standardize RT column name
df = df.rename(columns={df.columns[0]: "rt_min"})

# Coerce numerics
df["rt_min"] = pd.to_numeric(df["rt_min"], errors="coerce")
for c in df.columns[1:]:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# Slice RT window
rt_lo, rt_hi = RT_WINDOW
win = df[(df["rt_min"] >= rt_lo) & (df["rt_min"] <= rt_hi)].copy()

# Map columns -> charge states (e.g., "...+17H]")
charge_by_col = {}
for c in df.columns[1:]:
    m = re.search(r"\+(\d+)H", str(c))
    if m:
        charge_by_col[c] = int(m.group(1))

# Compute AUC per charge (trapezoid rule)
rows = []
for col, z in sorted(charge_by_col.items(), key=lambda kv: kv[1]):
    g = win[["rt_min", col]].dropna()
    if len(g) >= 2:
        g = g.sort_values("rt_min")
        auc = float(np.trapz(g[col].to_numpy(), g["rt_min"].to_numpy()))
    else:
        auc = 0.0
    rows.append({"charge": z, "auc_20_25": auc, "n_points": int(len(g))})

auc_df = pd.DataFrame(rows).sort_values("charge").reset_index(drop=True)
auc_df.to_csv(OUT_CSV, index=False)

# --------------------------
#     GAUSSIAN FIT
# --------------------------
def gaussian(z, A, mu, sigma, C):
    return A * np.exp(-((z - mu) ** 2) / (2.0 * sigma ** 2)) + C

z = auc_df["charge"].to_numpy(dtype=float)
y = auc_df["auc_20_25"].to_numpy(dtype=float)
mask = np.isfinite(z) & np.isfinite(y) & (y >= 0)
z_fit = z[mask]
y_fit = y[mask]

if len(z_fit) >= 3 and np.nanmax(y_fit) > 0:
    # Initial guesses
    C0   = float(np.min(y_fit))
    A0   = float(np.max(y_fit) - C0)
    mu0  = float(np.sum(z_fit * y_fit) / (np.sum(y_fit) + 1e-12))  # weighted mean
    sigma0 = float(np.sqrt(np.sum(y_fit * (z_fit - mu0) ** 2) / (np.sum(y_fit) + 1e-12)))
    sigma0 = sigma0 if sigma0 > 0 else max(1.0, (np.max(z_fit) - np.min(z_fit)) / 6.0)

    try:
        from scipy.optimize import curve_fit
        popt, pcov = curve_fit(
            gaussian,
            z_fit, y_fit,
            p0=[A0, mu0, sigma0, C0],
            bounds=([0, np.min(z_fit)-5, 1e-6, -np.inf],
                    [np.inf, np.max(z_fit)+5, np.inf,  np.inf]),
            maxfev=20000
        )
        A, mu, sigma, C = popt
    except Exception:
        # Fallback (no SciPy): fit quadratic to ln(y) assuming C≈0
        C = 0.0
        y_pos = np.maximum(y_fit, 1e-12)
        a, b, c = np.polyfit(z_fit, np.log(y_pos), 2)
        if a < 0:
            mu = -b / (2 * a)
            sigma = np.sqrt(-1 / (2 * a))
            A = np.exp(c - (mu ** 2) * a - b * mu)
        else:
            mu, sigma, A = mu0, sigma0, A0

    # Grid + metrics
    z_grid = np.linspace(np.min(z_fit), np.max(z_fit), 400)
    y_grid = gaussian(z_grid, A, mu, sigma, C)
    y_hat  = gaussian(z_fit, A, mu, sigma, C)
    ss_res = float(np.sum((y_fit - y_hat) ** 2))
    ss_tot = float(np.sum((y_fit - np.mean(y_fit)) ** 2)) + 1e-12
    r2     = 1.0 - ss_res / ss_tot
    fwhm   = 2.354820045 * sigma

    # ---- PLOT: scatter data with Gaussian on top ----
    plt.figure(figsize=(10, 6))
    plt.scatter(z, y, s=50, label="AUC data")   # data points
    plt.plot(z_grid, y_grid, linewidth=2.5, label="Gaussian fit")  # overlayed fit
    plt.title(
        f"AUC vs Charge (RT {rt_lo:.2f}–{rt_hi:.2f} min)\n"
        f"Fit: A={A:,.3g}, μ={mu:,.3f}, σ={sigma:,.3f} (FWHM={fwhm:,.3f}), C={C:,.3g}, R²={r2:.4f}"
    )
    plt.xlabel("Charge State")
    plt.ylabel("Area Under Curve (Intensity × min)")
    plt.xlim((5,30))
    plt.legend()
    plt.tight_layout()
    plt.savefig(OUT_PNG, dpi=150)
    plt.show()

    print(f"Gaussian params: A={A:.6g}, mu={mu:.6f}, sigma={sigma:.6f}, C={C:.6g}, R^2={r2:.5f}, FWHM={fwhm:.6f}")
else:
    print("Not enough valid points to fit a Gaussian (need ≥3 finite AUC values).")

print(f"Saved AUC table: {OUT_CSV.resolve()}")
print(f"Saved plot (scatter + Gaussian): {OUT_PNG.resolve()}")
